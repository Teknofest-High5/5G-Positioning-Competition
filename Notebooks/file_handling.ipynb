# %%
import pandas as pd
import numpy as np
from path_config import PathConfig

# %%
paths = PathConfig()

# %%
dl = pd.read_excel(paths.dl_path ,sheet_name="Series Formatted Data")
dl = dl.drop(["Technology_Mode","Unnamed: 48"],axis=1)

# %%
dl["Time"] = dl["Time"].dt.floor('s')

# %%
new_dl = pd.DataFrame()

mean_cols = [
             "NR_UE_RSRP_0",
             "NR_UE_RSRQ_0",
             "NR_UE_SINR_0",	
             "NR_UE_Nbr_RSRP_0",	
             "NR_UE_Nbr_RSRP_1",
             "NR_UE_Nbr_RSRP_2",
             "NR_UE_Nbr_RSRP_3",
             "NR_UE_Nbr_RSRP_4",
             "NR_UE_Nbr_RSRQ_0",
             "NR_UE_Nbr_RSRQ_1",
             "NR_UE_Nbr_RSRQ_2",
             "NR_UE_Nbr_RSRQ_3",
             "NR_UE_Nbr_RSRQ_4"]

last_known_data_cols = [
                        "NR_UE_PCI_0",
                        "NR_UE_Nbr_PCI_0",
                        "NR_UE_Nbr_PCI_1",	
                        "NR_UE_Nbr_PCI_2",	
                        "NR_UE_Nbr_PCI_3",	
                        "NR_UE_Nbr_PCI_4",
                        ]

for row in dl['Time'].unique():

    filtered_row_mean = dl[dl["Time"] == row][mean_cols].mean()
    filtered_row_last = dl[dl["Time"] == row][last_known_data_cols]
    last_known_values = filtered_row_last.apply(lambda x: x.dropna().iloc[-1] if not x.dropna().empty else np.nan)
    filtered_row = pd.concat([pd.Series({'Time': row}), filtered_row_mean, last_known_values])
    new_dl = pd.concat([new_dl, filtered_row.to_frame().T], ignore_index=True)
             
new_dl
# Out:
#                      Time NR_UE_RSRP_0 NR_UE_RSRQ_0 NR_UE_SINR_0  \
# 0     2025-03-14 12:14:33        -87.1        -11.2          7.3
# 1     2025-03-14 12:14:34   -85.233333   -11.233333         6.25
# 2     2025-03-14 12:14:35       -86.25        -11.1        11.65
# 3     2025-03-14 12:14:36        -87.6       -10.55         11.6
# 4     2025-03-14 12:14:37       -86.65        -10.6         11.7
# ...                   ...          ...          ...          ...
# 1060  2025-03-14 12:32:13       -118.6        -13.2         2.45
# 1061  2025-03-14 12:32:14       -118.2       -13.55          2.4
# 1062  2025-03-14 12:32:15      -118.05       -13.25         0.15
# 1063  2025-03-14 12:32:16      -118.15        -13.1        -1.05
# 1064  2025-03-14 12:32:17       -119.6        -13.6         -1.6
#
#      NR_UE_Nbr_RSRP_0 NR_UE_Nbr_RSRP_1 NR_UE_Nbr_RSRP_2 NR_UE_Nbr_RSRP_3  \
# 0               -97.3              NaN              NaN              NaN
# 1          -96.266667              NaN              NaN              NaN
# 2              -98.25              NaN              NaN              NaN
# 3               -99.4              NaN              NaN              NaN
# 4              -96.85              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 1060          -122.85              NaN              NaN              NaN
# 1061          -120.85              NaN              NaN              NaN
# 1062           -121.2              NaN              NaN              NaN
# 1063          -121.25              NaN              NaN              NaN
# 1064          -121.85              NaN              NaN              NaN
#
#      NR_UE_Nbr_RSRP_4 NR_UE_Nbr_RSRQ_0 NR_UE_Nbr_RSRQ_1 NR_UE_Nbr_RSRQ_2  \
# 0                 NaN            -16.3              NaN              NaN
# 1                 NaN            -16.6              NaN              NaN
# 2                 NaN           -17.05              NaN              NaN
# 3                 NaN           -16.85              NaN              NaN
# 4                 NaN           -13.25              NaN              NaN
# ...               ...              ...              ...              ...
# 1060              NaN           -16.95              NaN              NaN
# 1061              NaN            -15.6              NaN              NaN
# 1062              NaN           -15.75              NaN              NaN
# 1063              NaN           -15.65              NaN              NaN
# 1064              NaN           -15.95              NaN              NaN
#
#      NR_UE_Nbr_RSRQ_3 NR_UE_Nbr_RSRQ_4 NR_UE_PCI_0 NR_UE_Nbr_PCI_0  \
# 0                 NaN              NaN        48.0            76.0
# 1                 NaN              NaN        48.0            76.0
# 2                 NaN              NaN        48.0            76.0
# 3                 NaN              NaN        48.0            76.0
# 4                 NaN              NaN        48.0            76.0
# ...               ...              ...         ...             ...
# 1060              NaN              NaN        68.0            59.0
# 1061              NaN              NaN        68.0            59.0
# 1062              NaN              NaN        68.0            59.0
# 1063              NaN              NaN        68.0            59.0
# 1064              NaN              NaN        68.0            59.0
#
#      NR_UE_Nbr_PCI_1 NR_UE_Nbr_PCI_2 NR_UE_Nbr_PCI_3 NR_UE_Nbr_PCI_4
# 0                NaN             NaN             NaN             NaN
# 1                NaN             NaN             NaN             NaN
# 2                NaN             NaN             NaN             NaN
# 3                NaN             NaN             NaN             NaN
# 4                NaN             NaN             NaN             NaN
# ...              ...             ...             ...             ...
# 1060             NaN             NaN             NaN             NaN
# 1061             NaN             NaN             NaN             NaN
# 1062             NaN             NaN             NaN             NaN
# 1063             NaN             NaN             NaN             NaN
# 1064             NaN             NaN             NaN             NaN
#
# [1065 rows x 20 columns]
